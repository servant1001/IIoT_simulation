# %% [markdown]
# # Phase 9 — IIoT Fault Classification
#
# 此 Notebook 使用 Phase 8 正式 Dataset。訓練標籤為 `actual_fault_type`；`predicted_fault_type` 不會參與訓練。

# %%
from pathlib import Path

dataset_path = Path('artifacts/iiot-fault-dataset.csv')
assert dataset_path.is_file(), '請先依 README 匯出 Phase 8 Dataset CSV。'
dataset_path

# %% [markdown]
# 正式訓練預設要求每種 Ground Truth Fault 有 100 個不同 Experiment Runs。資料不足時，請先繼續收集；`--allow-small-dataset` 僅用於驗證流程。

# %%
# !python ml/train.py --input artifacts/iiot-fault-dataset.csv --output ml/outputs/phase9

# %%
import pandas as pd

pd.read_csv('ml/outputs/phase9/leaderboard.csv')
